# %% [markdown]
# # Contents
# 1. Import Libraries and Data Set
# 2. Data Checks
# 3. Rename Column

# %% [markdown]
# # Import Libraries & Data Set

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path 
path = r'/Users/ATeam/Desktop/CF/Achievement 6 - Applied analytics/Air Pollution'

# %%
# Import data set 
df_air_pollution = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'air_pollution.csv'))

# %% [markdown]
# # Data Checks

# %%
# Check number of rows and columns 
df_air_pollution.shape
# Out:
# (6468, 7)

# %%
# Check the first 
df_air_pollution.head()
# Out:
#         Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0  Afghanistan  AFG  1990                                  299.477309
# 1  Afghanistan  AFG  1991                                  291.277967
# 2  Afghanistan  AFG  1992                                  278.963056
# 3  Afghanistan  AFG  1993                                  278.790815
# 4  Afghanistan  AFG  1994                                  287.162923
#
#    Indoor air pollution (deaths per 100,000)  \
# 0                                 250.362910
# 1                                 242.575125
# 2                                 232.043878
# 3                                 231.648134
# 4                                 238.837177
#
#    Outdoor particulate matter (deaths per 100,000)  \
# 0                                        46.446589
# 1                                        46.033841
# 2                                        44.243766
# 3                                        44.440148
# ...

# %%
# Check data frame value counts
df_air_pollution.value_counts
# Out:
# <bound method DataFrame.value_counts of            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
# Check for missing values
df_air_pollution.isnull()
# Out:
#       Entity   Code   Year  Air pollution (total) (deaths per 100,000)  \
# 0      False  False  False                                       False
# 1      False  False  False                                       False
# 2      False  False  False                                       False
# 3      False  False  False                                       False
# 4      False  False  False                                       False
# ...      ...    ...    ...                                         ...
# 6463   False  False  False                                       False
# 6464   False  False  False                                       False
# 6465   False  False  False                                       False
# 6466   False  False  False                                       False
# 6467   False  False  False                                       False
#
#       Indoor air pollution (deaths per 100,000)  \
# 0                                         False
# ...

# %%
#Check the value counts of the Entity column 
df_air_pollution.value_counts('Entity')
# Out:
# Entity
# Afghanistan                     28
# Niger                           28
# North Africa and Middle East    28
# North America                   28
# North Korea                     28
#                                 ..
# Grenada                         28
# Guam                            28
# Guatemala                       28
# Guinea                          28
# Zimbabwe                        28
# Name: count, Length: 231, dtype: int64

# %%
# Check descriptive statistics of data set 
df_air_pollution.describe()
# Out:
#               Year  Air pollution (total) (deaths per 100,000)  \
# count  6468.000000                                 6468.000000
# mean   2003.500000                                   87.804083
# std       8.078372                                   57.845436
# min    1990.000000                                    8.401696
# 25%    1996.750000                                   41.016114
# 50%    2003.500000                                   72.653557
# 75%    2010.250000                                  127.607177
# max    2017.000000                                  318.463253
#
#        Indoor air pollution (deaths per 100,000)  \
# count                                6468.000000
# mean                                   50.481504
# std                                    58.722565
# min                                     0.003859
# 25%                                     2.002779
# 50%                                    23.737851
# ...

# %% [markdown]
# # Rename Column

# %%
# Rename the Entity column 
df_air_pollution.rename(columns={'Entity': 'Country'})
# Out:
#           Country Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
# Export Data Frame
df_air_pollution.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'air_pollution_clean.csv'))
